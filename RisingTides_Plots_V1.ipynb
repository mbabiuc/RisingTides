# %% [markdown]
# ## Title: Rising Tides Script Revised
# #### authors: Alec O'Dell (undergraduate student) and Maria C. Babiuc Hamilton (physics professor)
# #### contact: babiuc@marshall.edu

# %%
# %autosave 0
# Out:
# Autosave disabled

# %% [markdown]
# ### Initialization

# %%
import RisingTides_workflow_V1 as RisingTides

# %%
import timeit
start_time = timeit.default_timer()
RisingTides.Run()
globals().update(RisingTides.retrieveresults())
elapsed = timeit.default_timer() - start_time
print(elapsed)
# Out:
# 21.06941019500664

# %%
#Paper-quality plots
import matplotlib
matplotlib.rcParams.update({'font.size': 14, 'font.family': 'STIXGeneral', 'mathtext.fontset': 'stix'})

fig = plt.figure(figsize=(11, 6))

axes1 = fig.add_axes([0.1, 0.1, 0.9, 0.8]) # main axes
axes2 = fig.add_axes([0.26, 0.65, 0.34, 0.23]) # inset axes
axes3 = fig.add_axes([0.14, 0.15, 0.30, 0.21]) # inset axes
axes4 = fig.add_axes([0.49, 0.15, 0.30, 0.21]) # inset axes
#rΔTref
# main figure
axes1.plot(BBHTime[BBHwi0:BBHiF]-BBHTime[BBHwi0],BBHh22plus[BBHwi0:BBHiF],'k', linewidth=1.15, label=r"$h^{BBH}_{+,NR}$")
axes1.plot(MtarrhybM-MtarrhybM[0],hplushybarr, linestyle='dashed', color='blue',linewidth=1.15,label=r"$h^{BBH}_{+,Ana}$")
axes1.set_xlabel('$t/M$',labelpad=-1)
axes1.set_xlim(0,3600)
axes1.set_ylabel("$h_{+}$",labelpad=-8)
axes1.legend(loc=2)
#axes1.set_title('strain')

# the hybrid strain peak is displaced
mrgAnahi=np.where(hplushybarr==np.max(hplushybarr))[0][0]
ΔThybM = MtarrhybM[mrgAnahi]-MtarrhybM[numM]
#print(ΔThybM)
# insert
axes2.plot((BBHTime[BBHwi0+8800:BBHiM+800]-BBHTime[BBHwi0]),BBHh22plus[BBHwi0+8800:BBHiM+800], 'k')
axes2.plot(MtarrhybM[numLR-1250:-1500]-MtarrhybM[0],hplushybarr[numLR-1250:-1500], linestyle='dashed', color='blue',linewidth=1.15)
axes2.plot(MtBoBarr[0:-2000]-MtBoBarr[0]+MtPNarr[numLR]+75, hplusBoBarr[0:-2000]/np.max(hplusBoBarr),linestyle='dotted', color='red',linewidth=1.15)
axes2.set_ylabel("$h_{+}$",labelpad=-10)
axes2.axvline(x=MtarrhybM[numLR]-MtarrhybM[0], color='y', ls='--')
axes2.set_xlim(3350,3600)
#axes2.axvline(x=BBHTime[BBHiM], color='y', ls='--')


#axes3.plot(BBHTime[BBHwi0:BBHiM]-BBHTime[BBHwi0],BBHϕ[BBHwi0:BBHiM]-BBHϕ[BBHwi0], 'k',label=r"$M\phi_{NR}$")
#axes3.plot(MtarrhybM[0:numM]-MtarrhybM[0],Mϕhybarr[0:numM]-Mϕhybarr[0], linestyle='dashed', color='blue',linewidth=1.15,label=r"$M\phi_{hyb}$")
axes3.plot(MtarrhybM[1:numM]-MtarrhybM[0],ΔϕAnaBBH[1:numM], 'k', linewidth=1.15, label=r"$\Delta \phi_{NR-Ana}$")
axes3.legend(loc=2)
axes3.set_ylim(0,3)
axes3.axvline(x=MtarrhybM[numLR]-MtarrhybM[0], color='y', ls='--')
axes3.set_xlim(0,3600)
axes3.set_ylim(0,3)
axes3.set_ylabel("$\Delta \phi$",labelpad=-1)
#axes3.axvline(x=BNS2Tshift[mrgBNS2index], color='y', linestyle='dotted', linewidth=0.75)
#axes3.set_title('Phase Comparison');

ΔlogAnaBBH = np.log(Amphybarr/Amphybarr[0])-np.log(BBHϕintarr/BBHϕintarr[0])
#axes4.plot(BBHTime[BBHwi0:BBHiM]-BBHTime[BBHwi0],BBHAmp[BBHwi0:BBHiM], 'k')
#axes4.plot(MtarrhybM[0:numM]-MtarrhybM[0],Amphybarr[0:numM], linestyle='dashed', color='blue',linewidth=1.15,label=r"$A_{hyb}$")
axes4.plot(MtarrhybM[0:numM]-MtarrhybM[0],ΔAmpAnaBBH[0:numM], 'k', linewidth=1.15, label=r"$\Delta A_{NR-Ana}$")
axes4.legend(loc=2)
axes4.set_ylim(0,0.5)
axes4.axvline(x=MtarrhybM[numLR]-MtarrhybM[0], color='y', ls='--')
axes4.set_xlim(0,3600)
axes4.set_ylim(0,0.4)
axes4.set_ylabel("$\Delta A$",labelpad=-1)
#axes4.set_title('Amplitude Comparison');

#fig.savefig("Figure1.eps",bbox_inches='tight')
#print(ΔϕAnaBBH[mrgBNS1index])
# Out:
# Text(0, 0.5, '$\\Delta A$')

# %% [markdown]
# ### Compare with numerical SXS:NSNS:0001/0002

# %%
## Plots for paper 
dashdotdot = (0, (4, 1, 1, 1, 1, 1))
#Paper-quality plots
matplotlib.rcParams.update({'font.size': 13, 'font.family': 'STIXGeneral', 'mathtext.fontset': 'stix'})

fig = plt.figure(figsize=(10, 5))

axes1 = fig.add_axes([0.1, 0.1, 0.9, 0.8]) # main axes
axes2 = fig.add_axes([0.15, 0.28, 0.33, 0.32]) # inset axes
axes3 = fig.add_axes([0.55, 0.56, 0.33, 0.32]) # inset axes
#(x,y)

# main figure
#axes1.plot(BNS1Tshift, BBH1ϕintarr-BBH1ϕintarr[0], linestyle='solid', color='y',label=r"$M\phi_{NR}$")
axes1.plot(BNS1Tshift, AnaBBH1ϕintarr-AnaBBH1ϕintarr[0], linestyle='dotted', color='orange',label=r"$M\phi^{BBH}_{hyb}$")
axes1.plot(BNS1Tshift, BBH1ϕintarr-BBH1ϕintarr[0], linestyle='solid', color='black',label=r"$M\phi^{BBH}_{NR}$")
axes1.plot(BNS1Tshift, BNS1ϕintarr-BNS1ϕintarr[0], linestyle='dashed', color='blue',linewidth=1.15,label=r"$M\phi^{BNS1}_{NR}$")
axes1.plot(BNS2Tshift+ΔTrefBNS12, BNS2ϕintarr-BNS2ϕintarr[0]+ΔϕrefBNS12, linestyle='dashdot', color='green',linewidth=1.25,label=r"$M\phi^{BNS2}_{NR}$")
axes1.set_xlabel('$t/M$',labelpad=-2)
axes1.set_ylabel('$M\phi$',labelpad=-3)
axes1.set_xlim(0,3600)
axes1.legend(loc=2)

# insert
axes2.plot(BNS1Tshift[:mrgBNS1index], ΔϕBNS1BBH[:mrgBNS1index], linestyle='solid', color='blue',linewidth=1.05,label=r"$M\phi^{BNS1}_{T, NR}$")
axes2.plot(BNS1Tshift[:mrgBNS1index], BNS1ϕTidePN[:mrgBNS1index], linestyle='dotted', color='maroon',linewidth=1.10,label=r"$M\phi^{BNS1}_{T,pN} $")
axes2.plot(BNS1Tshift[:mrgBNS1index], BNS1ϕTideF1[:mrgBNS1index], linestyle=dashdotdot, color='red',linewidth=1.05,label=r"$M\phi^{BNS1}_{T,F1}$")
axes2.plot(BNS1Tshift[:mrgBNS1index], BNS1ϕTideF2[:mrgBNS1index], linestyle=dashdotdot, color='magenta',linewidth=1.05,label=r"$M\phi^{BNS1}_{F2}$")
#axes2.plot(BNS1Tshift[:mrgBNS1index], (AnaBBH1ϕintarr[:mrgBNS1index]-AnaBBH1ϕintarr[0])+BNS1ϕTidePNarr[:mrgBNS1index], linestyle='dotted', color='maroon',linewidth=1.05,label=r"$M\phi_{pN, BNS1}$")
#axes2.plot(BNS1Tshift[:mrgBNS1index], (AnaBBH1ϕintarr[:mrgBNS1index]-AnaBBH1ϕintarr[0])+BNS1ϕTideF1arr[:mrgBNS1index], linestyle=dashdotdot, color='red',linewidth=1.10,label=r"$M\phi_{F1, BNS1}$")
#axes2.plot(BNS1Tshift[:mrgBNS1index], (AnaBBH1ϕintarr[:mrgBNS1index]-AnaBBH1ϕintarr[0])+BNS1ϕTideF2arr[:mrgBNS1index], linestyle=dashdotdot, color='yellow',linewidth=1.10)
#axes2.set_title('Analytic $M\phi$, $\Lambda = 791$');
axes2.set_xlim(0,2999)
axes2.axhline(y=2, color='y', linestyle='dotted', linewidth=0.75)
#axes2.axvline(x=BNS1Tshift[mrgBNS1index], color='y', linestyle='dotted', linewidth=0.75)
axes2.set_ylabel('$M\phi$',labelpad=-5)
axes2.legend(loc=2)

axes3.plot(BNS2Tshift[:mrgBNS2index]+ΔTrefBNS12, ΔϕBNS2BBH[:mrgBNS2index], linestyle='solid', color='green',linewidth=1.05,label=r"$M\phi^{BNS2}_{T, NR}$")
axes3.plot(BNS2Tshift[:mrgBNS2index]+ΔTrefBNS12, BNS2ϕTidePN[:mrgBNS2index], linestyle='dotted', color='maroon',linewidth=1.10,label=r"$M\phi^{BNS2}_{T,pN}$")
axes3.plot(BNS2Tshift[:mrgBNS2index]+ΔTrefBNS12, BNS2ϕTideF1[:mrgBNS2index], linestyle=dashdotdot, color='red',linewidth=1.05,label=r"$M\phi^{BNS2}_{T,F1}$")
axes3.plot(BNS2Tshift[:mrgBNS2index]+ΔTrefBNS12, BNS2ϕTideF2[:mrgBNS2index], linestyle=dashdotdot, color='magenta',linewidth=1.05,label=r"$M\phi^{BNS2}_{F2}$")
#axes3.plot(BNS2Tshift[:mrgBNS2index]+ΔTrefBNS12, BNS2ϕintarr[:mrgBNS2index]-BNS2ϕintarr[0], linestyle='dashdot', color='cyan',linewidth=1.15)
#axes3.plot(BNS2Tshift[:mrgBNS2index]+ΔTrefBNS12, (AnaBBH2ϕintarr[:mrgBNS2index]-AnaBBH2ϕintarr[0])+BNS2ϕTidePNarr[:mrgBNS2index], linestyle='dotted', color='maroon',linewidth=1.05, label=r"$M\phi_{pN, BNS2}$")
#axes3.plot(BNS2Tshift[:mrgBNS2index]+ΔTrefBNS12, (AnaBBH2ϕintarr[:mrgBNS2index]-AnaBBH2ϕintarr[0])+BNS2ϕTideF1arr[:mrgBNS2index], linestyle=dashdotdot, color='red',linewidth=1.10, label=r"$M\phi_{F1, BNS2}$")
#axes3.plot(MtarrhybMshift2[:Mωhybimrg2]+ΔTrefhyb2,Mϕhybarrshift2[:Mωhybimrg2]+BNS2ϕTideF1arr[:Mωhybimrg2]+Δϕrefhyb2, linestyle=dashdotdot, color='red',linewidth=1.10)
#axes3.set_title('Analytic $M\phi$, $\Lambda = 1540$');
axes3.set_xlim(1160,2900)
axes3.axhline(y=2, color='y', linestyle='dotted', linewidth=0.75)
#axes3.set_ylim(0,10)
axes3.set_ylabel('$M\phi$',labelpad=-5)
axes3.legend(loc=2)

#fig.savefig("Figure2.eps",bbox_inches='tight')

# %%
fact1 = BBHAmp[BBH1wi0]/BNS1Amp[BNS1wi0]
fact2 = BBHAmp[BBH2wi0]/BNS2Amp[BNS2wi0]
# merger locations mrgBNS1index, mrgBNS2index
#Paper-quality plots
matplotlib.rcParams.update({'font.size': 13, 'font.family': 'STIXGeneral', 'mathtext.fontset': 'stix'})

fig = plt.figure(figsize=(10, 5))

axes1 = fig.add_axes([0.1, 0.1, 0.9, 0.8]) # main axes
axes2 = fig.add_axes([0.27, 0.45, 0.55, 0.45]) # inset axes
#axes3 = fig.add_axes([0.30, 0.15, 0.35, 0.15]) # inset axes

# main figure
axes1.plot(BNS1Tshift[0:],Amphybarr[numBNS1ref:], linestyle='dashed', color='orange',linewidth=1.2,label=r"$A^{BBH}_{hyb}$")
axes1.plot(BNS1Tshift[0:],BBH1Ampintarr[0:], linestyle='solid', color='black',linewidth=1.15,label=r"$A^{BBH}_{NR}$")
axes1.plot(BNS1Tshift[0:],fact1*BNS1Ampintarr[0:], linestyle='dashed', color='blue',linewidth=1.15,label=r"$A^{BNS1}_{NR}$")
axes1.plot(BNS2Tshift[0:]+ΔTrefBNS12,fact2*BNS2Ampintarr[0:], linestyle='dashdot', color='green',linewidth=1.15,label=r"$A^{BNS2}_{NR}$")
axes1.set_xlabel('$t/M$',labelpad=-3)
axes1.set_ylabel('$A/M$',labelpad=-1)
axes1.legend(loc=2)
axes1.set_xlim(0,3450)
#axes1.set_title('title')

# insert
axes2.plot(BBHTime[BBHwi0:] - BBHTime[BBH1wi0],BBHh22plus[BBHwi0:], color='black',linewidth=1.05, label=r"$h^{BBH}_{+,NR}$")
axes2.plot(BNS1Time[TrefBNS1:-700] - BNS1Time[TrefBNS1],scalehBNS1*BNS1h22plus[TrefBNS1:-700], linestyle='dashed', color='blue',linewidth=1.15, label=r"$h^{BNS1}_{+,NR}$")
axes2.plot(BNS2Time[TrefBNS2:] - BNS2Time[TrefBNS2]+ΔTrefBNS12,scalehBNS2*BNS2h22plus[TrefBNS2:], linestyle='dashdot', color='green',linewidth=1.15, label=r"$h^{BNS2}_{+,NR}$")
axes2.set_ylabel('$h_{+}$',labelpad=-10)
axes2.set_xlim(0,3450)
axes2.legend(loc=3)
#axes2.set_title('Strain Comparison BBH')

#fig.savefig("Figure3.eps",bbox_inches='tight')

# %%
# form the ratios of amplitudes
rAmpAnaBBH = (Amphybarr[numBNS1ref:numBNS1fin]/Amphybarr[0])/(BBHAintarr[numBNS1ref:numBNS1fin]/BBHAintarr[0])

## Plots for paper 
dashdotdot = (0, (4, 1, 1, 1, 1, 1))
#Paper-quality plots
matplotlib.rcParams.update({'font.size': 13, 'font.family': 'STIXGeneral', 'mathtext.fontset': 'stix'})

fig = plt.figure(figsize=(10, 5))

axes1 = fig.add_axes([0.1, 0.1, 0.9, 0.8]) # main axes
axes2 = fig.add_axes([0.16, 0.18, 0.35, 0.44]) # inset axes
axes3 = fig.add_axes([0.57, 0.18, 0.35, 0.44]) # inset axes 

# main figure
#Amphybarr[numBNS1ref:]/BBH1Ampintarr

axes1.plot(BNS1Tshift,rAmpAnaBBH, linestyle='solid', color='black',linewidth=1.10,label=r"$A^{BBH}_{hyb}/A^{BBH}_{NR}$")
axes1.plot(BNS1Tshift[0:numIDX1],BNS1Ampintarr[0:numIDX1]*fact1/BBH1Ampintarr[0:numIDX1], linestyle='dashed', color='blue',linewidth=1.15,label=r"$A^{BNS1}_{NR}\slash A^{BBH}_{NR}$")
axes1.plot(BNS2Tshift+ΔTrefBNS12, BNS2Ampintarr*fact2/BBH2Ampintarr, linestyle='dashdot', color='green',linewidth=1.15,label=r"$A^{BNS2}_{NR}\slash A^{BBH}_{NR}$")
axes1.set_xlabel('$t/M$',labelpad=-5)
axes1.set_ylabel('$A^{BNS}_{NR}\slash A^{BBH}_{NR}$',labelpad=+1)
axes1.set_xlabel('$t/M$',labelpad=-3)
axes1.legend(loc=2)
axes1.set_xlim(0,3200)
axes1.set_ylim(-0.01,+1.45)

axes2.plot(BNS1Tshift[:mrgBNS1index],BNS1AmpTideNR[:mrgBNS1index],linestyle='solid', color='black',linewidth=1.10,label=r"$A^{BNS1}_{T, NR}$")
axes2.plot(BNS1Tshift[:mrgBNS1index],BNS1PNATide[0:mrgBNS1index],linestyle="dashdot", color='red',linewidth=1.10,label=r"$A^{BNS1}_{T, pN}$")
axes2.plot(BNS1Tshift[:mrgBNS1index],BNS1AnaATide[0:mrgBNS1index],linestyle=dashdotdot, color='magenta',linewidth=1.10,label=r"$A^{BNS1}_{T,d}$")
axes2.set_ylabel('$A^{BNS1}_{T}$',labelpad=-1)
axes2.legend(loc=2)
axes2.set_xlim(0,3050)
axes2.set_ylim(-0.05,+0.4)

axes3.plot(BNS2Tshift[:mrgBNS2index]+ΔTrefBNS12,BNS2AmpTideNR[:mrgBNS2index],linestyle='solid', color='black',linewidth=1.10,label=r"$A^{BNNS2}_{T, NR}$")
axes3.plot(BNS2Tshift[:mrgBNS2index]+ΔTrefBNS12,BNS2PNATide[0:mrgBNS2index],linestyle="dashdot", color='red',linewidth=1.10,label=r"$A^{BNS1}_{T,pN}$")
axes3.plot(BNS2Tshift[:mrgBNS2index]+ΔTrefBNS12,BNS2AnaATide[0:mrgBNS2index],linestyle=dashdotdot, color='magenta',linewidth=1.10,label=r"$A^{BNS2}_{T,d}$")
axes3.set_ylabel('$A^{BNS2}_{T}$',labelpad=-1)
axes3.legend(loc=2)
axes3.set_xlim(1100,2900)
axes3.set_ylim(-0.05,+0.4)

#fig.savefig("Figure4.eps",bbox_inches='tight')
# Out:
# (-0.05, 0.4)

# %%
## is the data smooth? Calculate phase and amplitude from strain!
#Amp(hplus,hcros)
#Amp = np.sqrt(((hplus)**2)+((hcros)**2))
#np.arctan
#np.unwrap(2*(x+np.pi/2))/2-np.pi/2
from scipy.ndimage import gaussian_filter

# read raw data
BBHh22cros_raw = np.genfromtxt('Imh22BBH0180_raw.dat', unpack=True)
BNS1h22cros_raw = np.genfromtxt('Imh22BNS0001_raw.dat', unpack=True)
BNS2h22cros_raw = np.genfromtxt('Imh22BNS0002_raw.dat', unpack=True)

# read crossstrain component
BBHh22cros = BBHh22cros_raw[1,:]
BNS1h22cros = BNS1h22cros_raw[1,:]
BNS2h22cros = BNS2h22cros_raw[1,:]

# calculate amplitude directly from NR data
BBHhAmp = Amp(BBHh22plus,BBHh22cros)
BNS1hAmp = Amp(BNS1h22plus,BNS1h22cros)
BNS2hAmp = Amp(BNS2h22plus,BNS2h22cros)
#plt.plot((BBHTime[BBHwi0+8800:BBHiM+800]-BBHTime[BBHwi0]),BBHh22cros[BBHwi0+8800:BBHiM+800], 'k')

#calculate phase directly from NR data
arctanBBHh = np.arctan((BBHh22cros)/(BBHh22plus))
arctanBNS1h = np.arctan((BNS1h22cros)/(BNS1h22plus))
arctanBNS2h = np.arctan((BNS2h22cros)/(BNS2h22plus))
BBHhϕ = -np.unwrap(2*(arctanBBHh))/2+np.pi
BNS1hϕ = -np.unwrap(2*(arctanBNS1h))/2+np.pi
BNS2hϕ = -np.unwrap(2*(arctanBNS2h))/2+np.pi

sBBHhϕ = gaussian_filter(BBHhϕ, sigma=1)
sBNS1hϕ = gaussian_filter(BNS1hϕ, sigma=1)
sBNS2hϕ = gaussian_filter(BNS2hϕ, sigma=1)

# calculate frequency directly from NR data
BBHhω=np.gradient(sBBHhϕ,BBHTime)
BNS1hω=np.gradient(sBNS1hϕ,BNS1Time)
BNS2hω=np.gradient(sBNS2hϕ,BNS2Time)

intBBHhω=cumtrapz(BBHhω,BBHTime, initial=0)
intBBH1hω=cumtrapz(BBHhω[BBH1wi0:],BBHTime[BBH1wi0:], initial=0)
intBNS1hω=cumtrapz(BNS1hω[BNS1wi0:iTfinBNS1],BNS1Time[BNS1wi0:iTfinBNS1], initial=0)
intBBH2hω=cumtrapz(BBHhω[BBH2wi0:],BBHTime[BBH2wi0:], initial=0)
intBNS2hω=cumtrapz(BNS2hω[BNS2wi0:],BNS2Time[BNS2wi0:], initial=0)

from scipy.signal import find_peaks

peaksω1, _ = find_peaks(BNS1ω, height=1)
peaksω2, _ = find_peaks(BNS2ω, height=1)

print(peaksω1[-1], peaksω2[-1])

#plt.plot(BNS1Time[TrefBNS1:TrefBNS1+1000],BNS1ω[TrefBNS1:TrefBNS1+1000])
#plt.plot(BNS1Time[TrefBNS1:TrefBNS1+2000],BNS1hϕ[TrefBNS1:TrefBNS1+2000])

# fit a line through instead of taking the derivative
BNS1ω0 = np.polyfit(BNS1Time[TrefBNS1:TrefBNS1+10], BNS1hϕ[TrefBNS1:TrefBNS1+10], 1)
m, b = BNS1ω0 
print(BNS1ω0[0], BNS1hω[TrefBNS1],BNS1ω0[0]- BNS1hω[TrefBNS1] )

#plt.plot(BNS1Time[TrefBNS1-100:TrefBNS1+100],BNS1hω[TrefBNS1-100:TrefBNS1+100])
#plt.plot(BBHTime[BBHwi0-100:BBHwi0+1000], BBHω[BBHwi0-100:BBHwi0+1000])

#plt.plot(BBHTime[BBH1wi0:]-BBHTime[BBH1wi0],BBHhϕ[BBH1wi0:]-BBHhϕ[BBH1wi0])
#plt.plot(BNS1Time[BNS1wi0:iTfinBNS1]-BNS1Time[BNS1wi0],BNS1hϕ[BNS1wi0:iTfinBNS1]-BNS1hϕ[BNS1wi0])
#plt.plot(BNS1Time[BNS1wi0:iTfinBNS1]-BNS1Time[BNS1wi0],(sBNS1hϕ[BNS1wi0:iTfinBNS1]-sBNS1hϕ[BNS1wi0])-(BNS1hϕ[BNS1wi0:iTfinBNS1]-BNS1hϕ[BNS1wi0]))

#plt.plot(BBHTime[BBH1wi0:BBH1wi0+425]-BBHTime[BBH1wi0],BBHhω[BBH1wi0:BBH1wi0+425])
#plt.plot(BNS1Time[BNS1wi0:BNS1wi0+1000]-BNS1Time[BNS1wi0],BNS1hω[BNS1wi0:BNS1wi0+1000])

#plt.plot(BBHTime[BBH1wi0:]-BBHTime[BBH1wi0],intBBH1hω)
#plt.plot(BBHTime[BBH1wi0:BBH1wi0+425]-BBHTime[BBH1wi0],BBHhϕ[BBH1wi0:BBH1wi0+425]-BBHhϕ[BBH1wi0])
#plt.plot(BNS1Time[BNS1wi0:iTfinBNS1]-BNS1Time[BNS1wi0],intBNS1hω)
#plt.plot(BNS1Time[BNS1wi0:iTfinBNS1]-BNS1Time[BNS1wi0],BNS1hϕ[BNS1wi0:iTfinBNS1]-BNS1hϕ[BNS1wi0])

#ΔBNS1hϕ = intBNS1hω - (BNS1hϕ[BNS1wi0:iTfinBNS1]-BNS1hϕ[BNS1wi0])
#plt.plot(BNS1Time[BNS1wi0:iTfinBNS1]-BNS1Time[BNS1wi0],ΔBNS1hϕ)
#plt.plot(BNS1Time[BNS1wi0:BNS1wi0+1000]-BNS1Time[BNS1wi0],BNS1hϕ[BNS1wi0:BNS1wi0+1000])
#plt.plot(BBHTime[BBH1wi0:BBH1wi0+425]-BBHTime[BBH1wi0],BBHhϕ[BBH1wi0:BBH1wi0+425]-BBHhϕ[BBH1wi0])
#plt.plot(BNS1Time[BNS1wi0:BNS1wi0+1000]-BNS1Time[BNS1wi0],BNS1hϕ[BNS1wi0:BNS1wi0+1000]-BNS1hϕ[BNS1wi0])
#print((BNS1hϕ[BNS1wi0+1000]-BNS1hϕ[BNS1wi0])-(BBHhϕ[BBH1wi0+425]-BBHhϕ[BBH1wi0]))

#plt.plot(BNS2Time[BNS2wi0:BNS2wi0+1000],BNS2hϕ[BNS2wi0:BNS2wi0+1000])
#plt.plot(BNS2Time[6200:6204],BNS2ω[6200:6204])
#plt.plot(BNS2Time[6200:6204],BNS2hω[6200:6204])
# Out:
# 11428 6207
# 0.03522892057299221 0.03523357413549277 -4.653562500560315e-06

# %%
# Check if numerical tidal phase has negative values anywhere:
negΔϕBNS1BBH = np.any(ΔϕBNS1BBH[:mrgBNS1index]<0)
negΔϕBNS2BBH = np.any(ΔϕBNS2BBH[:mrgBNS2index]<0)

print("negative negΔϕBNS1BBH", negΔϕBNS1BBH)
print("negative negΔϕBNS2BBH", negΔϕBNS2BBH)

negΔϕBNS1Ana = np.any(ΔϕBNS1Ana[:mrgBNS1index]<0)
negΔϕBNS2Ana = np.any(ΔϕBNS2Ana[:mrgBNS2index]<0)

print("negative negΔϕBNS1Ana", negΔϕBNS1Ana)
print("negative negΔϕBNS2Ana", negΔϕBNS2Ana)

negBNS1ϕTidePN = np.any(BNS1ϕTidePN[:mrgBNS1index]<0)
negBNS1ϕTideF1 = np.any(BNS1ϕTideF1[:mrgBNS1index]<0)
negBNS1ϕTideF2 = np.any(BNS1ϕTideF2[:mrgBNS1index]<0)

print("negative negBNS1ϕTidePN", negBNS1ϕTidePN)
print("negative negBNS1ϕTideF1", negBNS1ϕTideF1)
print("negative negBNS1ϕTideF2", negBNS1ϕTideF2)
# Out:
# negative negΔϕBNS1BBH True
# negative negΔϕBNS2BBH True
# negative negΔϕBNS1Ana True
# negative negΔϕBNS2Ana True
# negative negBNS1ϕTidePN False
# negative negBNS1ϕTideF1 False
# negative negBNS1ϕTideF2 False

# %%
# establish the comparison interval

print(len(BNS1Tshift[iTiniBNS2BNS1:iTfinBNS2BNS1]))
print(len(BNS2Tshift))
plt.plot(BNS2Tshift, (BBHϕintarr[iTinBBH2:iTfinBBH2]-BBHϕintarr[iTinBBH2]),color='black',linewidth=1.15,label=r"$M\phi^{BBH}_{NR}$")
plt.plot(BNS2Tshift, (BNS1ϕintarr[iTiniBNS2BNS1:iTfinBNS2BNS1]-BNS1ϕintarr[iTiniBNS2BNS1]), linestyle='dashed', color='blue',linewidth=1.15,label=r"$M\phi^{BNS1}_{NR}$")
plt.plot(BNS2Tshift, (BNS2ϕintarr-BNS2ϕintarr[0]), linestyle='dashdot', color='green',linewidth=1.25,label=r"$M\phi^{BNS2}_{NR}$")
plt.legend(loc=2)
# Out:
# 21403
# 21403

# %%
#array for BNS1 for BNS2Tshift.

plt.plot(BNS2Tshift, (ΔϕBNS1), linestyle='dashed', color='blue',linewidth=1.15,label=r"$M\Delta phi^{BNS1}_{NR}$")
plt.plot(BNS2Tshift, (ΔϕBNS2), linestyle='dashdot', color='green',linewidth=1.25,label=r"$M\Delta phi^{BNS2}_{NR}$")
plt.axvline(x=BNS2Tshift[mrgBNS2index], linestyle='dotted', color='magenta',linewidth=0.75)
plt.legend(loc=2)

# %%
# numerical tide vs analytical approx, no tidal coeffs
#plt.plot(BNS2Tshift[0:mrgBNS2index], (ΔϕBNS1[0:mrgBNS2index]), linestyle='dashed', color='blue',linewidth=1.15,label=r"$M\Delta phi^{BNS1}_{NR}$")
#plt.plot(BNS2Tshift[0:mrgBNS2index], (ΔϕBNS2[0:mrgBNS2index]), linestyle='dashdot', color='green',linewidth=1.25,label=r"$M\Delta phi^{BNS2}_{NR}$")

plt.plot(BNS2Tshift[0:mrgBNS2index], (ΔϕBNS1[0:mrgBNS2index]), linestyle='dashed', color='blue',linewidth=1.15,label=r"$M\Delta phi^{BNS1}_{NR}$")
plt.plot(BNS2Tshift[0:mrgBNS2index], (ΔϕBNS2[0:mrgBNS2index]), linestyle='dashdot', color='green',linewidth=1.25,label=r"$M\Delta phi^{BNS2}_{NR}$")
plt.plot(BNS2Tshift[0:mrgBNS2index], BNS2ϕTideNR[0:mrgBNS2index])
#plt.plot(BNS2Tshift[0:mrgBNS2index], BNS2ϕTidePN[0:mrgBNS2index]/BNS2tΛ)
#plt.plot(BNS2Tshift[0:mrgBNS2index], BNS2ϕTideF1[0:mrgBNS2index]/BNS2tΛ)
#plt.plot(BNS2Tshift[0:mrgBNS2index], BNS2ϕTideF2[0:mrgBNS2index]/BNS2tΛ)
plt.legend(loc=2)

# %%
chosen_params_BNS1 = compare_models_residuals(ΔϕBNS1[0:mrgBNS2index], ΔϕBNS1FitPN[0:mrgBNS2index], ΔϕBNS1FitF1[0:mrgBNS2index], ΔϕBNS1FitF2[0:mrgBNS2index], pBNS1fit_PN, pBNS1fit_F1, pBNS1fit_F2)
print(f"Chosen Model parameters BNS1: {chosen_params_BNS1}")
# Out:
# Chosen Model parameters BNS1: (array([ -214.94904135,  2016.23029914, -7743.40409987, 13772.45168073,
#        -9381.96489336,   -42.62261525,   151.06265795,  -150.08487614]), 'params3')

# %%
plt.plot(BNS2Tshift[0:mrgBNS2index], (ΔϕBNS1[0:mrgBNS2index]), linestyle='dashed', color='blue',linewidth=1.15,label=r"$M\\Delta phi^{BNS1}_{NR}$")
plt.plot(BNS2Tshift[0:mrgBNS2index], ΔϕBNS1FitPN[0:mrgBNS2index])
plt.plot(BNS2Tshift[0:mrgBNS2index], ΔϕBNSAnaPN[0:mrgBNS2index])
#plt.plot(BNS2Tshift[0:mrgBNS2index], ΔϕBNS1FitF1[0:mrgBNS2index])
#plt.plot(BNS2Tshift[0:mrgBNS2index], ΔϕBNS1FitF2[0:mrgBNS2index])

# %%
plt.plot(BNS2Tshift[0:mrgBNS2index], (ΔϕBNS2[0:mrgBNS2index]), linestyle='dashdot', color='blue',linewidth=1.25,label=r"$M\\Delta phi^{BNS2}_{NR}$")
plt.plot(BNS2Tshift[0:mrgBNS2index], ΔϕBNS2FitPN[0:mrgBNS2index])
plt.plot(BNS2Tshift[0:mrgBNS2index], ΔϕBNSAnaPN[0:mrgBNS2index])
#plt.plot(BNS2Tshift[0:mrgBNS2index], ΔϕBNS2FitF1[0:mrgBNS2index])
#plt.plot(BNS2Tshift[0:mrgBNS2index], ΔϕBNS2FitF2[0:mrgBNS2index])

# %%
chosen_params_BNS2 = compare_models_residuals(ΔϕBNS2[0:mrgBNS2index], ΔϕBNS2FitPN[0:mrgBNS2index], ΔϕBNS2FitF1[0:mrgBNS2index], ΔϕBNS2FitF2[0:mrgBNS2index], pBNS2fit_PN, pBNS2fit_F1, pBNS2fit_F2)
print(f"Chosen Model parameters BNS2: {chosen_params_BNS2}")
# Out:
# Chosen Model parameters BNS2: (array([  -1709.58544064,   22761.50655787, -113786.70945816,
#         249902.54945476, -202212.41167941,     735.35708525,
#          -4397.80932046,    6519.1232231 ]), 'params2')

# %%
# Compare residuals
# Calculate the sum of squared residuals
chosen_params = compare_residuals(ΔϕBNS1[0:mrgBNS2index], ΔϕBNS1FitF2[0:mrgBNS2index], ΔϕBNS2[0:mrgBNS2index], ΔϕBNS2FitF1[0:mrgBNS2index], pBNS1fit_F2, pBNS2fit_F1)
print(f"Chosen parameters: {chosen_params}")
# Out:
# Parameters from the first dataset provide a better fit.
# Chosen parameters: [ -214.94904135  2016.23029914 -7743.40409987 13772.45168073
#  -9381.96489336   -42.62261525   151.06265795  -150.08487614]

# %%
print(f"Chosen parameters ratio: {pBNS1fit_F2/pBNS2fit_F1}")
# Out:
# Chosen parameters ratio: [ 0.12573168  0.08858071  0.06805192  0.05511129  0.04639658 -0.05796179
#  -0.03434952 -0.02302225]

# %%
## pBNS1fit_PN are chosen, now calculate SSR for the dataset

R_squared_BNS1_orig = calculate_r_squared(ΔϕBNS1[0:mrgBNS2index], ΔϕBNSAnaPN[0:mrgBNS2index])
print(f"R² for the original fit PN BNS1: {R_squared_BNS1_orig}")

R_squared_BNS2_orig = calculate_r_squared(ΔϕBNS2[0:mrgBNS2index], ΔϕBNSAnaPN[0:mrgBNS2index])
print(f"R² for the original fit PN BNS2: {R_squared_BNS2_orig}")

R_squared_BNS1_new = calculate_r_squared(ΔϕBNS1[0:mrgBNS2index], ΔϕBNS1FitPN[0:mrgBNS2index])
print(f"R² for the new fit PN BNS1: {R_squared_BNS1_new}")

R_squared_BNS2_new = calculate_r_squared(ΔϕBNS2[0:mrgBNS2index], ΔϕBNS2FitPN[0:mrgBNS2index])
print(f"R² for the new fit PN BNS2: {R_squared_BNS2_new}")
# Out:
# R² for the original fit PN BNS1: -53.74324228910621
# R² for the original fit PN BNS2: -36.95234853042547
# R² for the new fit PN BNS1: 0.7185443243565937
# R² for the new fit PN BNS2: 0.7774316468536142

# %%
## pBNS1fit_F1 are chosen, now calculate SSR for the dataset

R_squared_BNS1_orig = calculate_r_squared(ΔϕBNS1[0:mrgBNS2index], ΔϕBNSAnaF1[0:mrgBNS2index])
print(f"R² for the original fit F1 BNS1: {R_squared_BNS1_orig}")

R_squared_BNS2_orig = calculate_r_squared(ΔϕBNS2[0:mrgBNS2index], ΔϕBNSAnaF1[0:mrgBNS2index])
print(f"R² for the original fit F1 BNS2: {R_squared_BNS2_orig}")

R_squared_BNS1_new = calculate_r_squared(ΔϕBNS1[0:mrgBNS2index], ΔϕBNS1FitF1[0:mrgBNS2index])
print(f"R² for the new fit F1 BNS1: {R_squared_BNS1_new}")

R_squared_BNS2_new = calculate_r_squared(ΔϕBNS2[0:mrgBNS2index], ΔϕBNS2FitF1[0:mrgBNS2index])
print(f"R² for the new fit F1 BNS2: {R_squared_BNS2_new}")
# Out:
# R² for the original fit F1 BNS1: -133.28835921963045
# R² for the original fit F1 BNS2: -86.98901650104915
# R² for the new fit F1 BNS1: 0.7185340704607315
# R² for the new fit F1 BNS2: 0.777497095857431

# %%
## pBNS1fit_F2 are chosen, now calculate SSR for the dataset

R_squared_BNS1_orig = calculate_r_squared(ΔϕBNS1[0:mrgBNS2index], ΔϕBNSAnaF2[0:mrgBNS2index])
print(f"R² for the original fit F2 BNS1: {R_squared_BNS1_orig}")

R_squared_BNS2_orig = calculate_r_squared(ΔϕBNS2[0:mrgBNS2index], ΔϕBNSAnaF2[0:mrgBNS2index])
print(f"R² for the original fit F2 BNS2: {R_squared_BNS2_orig}")

R_squared_BNS1_new = calculate_r_squared(ΔϕBNS1[0:mrgBNS2index], ΔϕBNS1FitF2[0:mrgBNS2index])
print(f"R² for the new fit F2 BNS1: {R_squared_BNS1_new}")

R_squared_BNS2_new = calculate_r_squared(ΔϕBNS2[0:mrgBNS2index], ΔϕBNS2FitF2[0:mrgBNS2index])
print(f"R² for the new fit F2 BNS2: {R_squared_BNS2_new}")

ΔϕBNS2FitBNS1F2 = AnaϕTide(Xhybarr[numBNS2ref:numBNS2fin],*pBNS1fit_F2)
ΔϕBNS2FitBNS1F2 = ΔϕBNS2FitBNS1F2 - ΔϕBNS2FitBNS1F2[0]

R_squared_BNS2_BNS1 = calculate_r_squared(ΔϕBNS2[0:mrgBNS2index], ΔϕBNS2FitBNS1F2[0:mrgBNS2index])
print(f"R² for the new fit F2 BNS2: {R_squared_BNS2_BNS1}")
# Out:
# R² for the original fit F2 BNS1: -53.74324228910621
# R² for the original fit F2 BNS2: -36.95234853042547
# R² for the new fit F2 BNS1: 0.7186735384569158
# R² for the new fit F2 BNS2: 0.7773141619595718
# R² for the new fit F2 BNS2: 0.1812696746053889

# %%
# Plotting the new dataset and the model predictions
plt.figure(figsize=(8, 5))
plt.plot(BNS2Tshift[0:mrgBNS2index], ΔϕBNS2[0:mrgBNS2index], 'o', label='Numeric BNS2')
plt.plot(BNS2Tshift[0:mrgBNS2index], ΔϕBNSAnaF1[0:mrgBNS2index], label='Orig F1 fit')
plt.plot(BNS2Tshift[0:mrgBNS2index], ΔϕBNS2FitBNS1F2[0:mrgBNS2index], '-', label='BNS1 F2 New Fit')
plt.plot(BNS2Tshift[0:mrgBNS2index], ΔϕBNS2FitF1[0:mrgBNS2index], '-', label='BNS2 F1 New Fit')
plt.xlabel('x')
plt.ylabel('$\Delta \phi$')
plt.title('Fit to New Data Using Chosen Parameters')
plt.legend()
plt.show()

# %%
# Plotting the new dataset and the model predictions
ΔϕBNS1FitBNS2F1 = AnaϕTide(Xhybarr[iTiniBNS2BNS1:iTfinBNS2BNS1],*pBNS2fit_F1)
ΔϕBNS1FitBNS2F1 = ΔϕBNS1FitBNS2F1 - ΔϕBNS1FitBNS2F1[0]
R_squared_BNS1_BNS2new = calculate_r_squared(ΔϕBNS1[0:mrgBNS2index], ΔϕBNS1FitBNS2F1[0:mrgBNS2index])
print(f"R² for the new fit BNS1 with F1 BNS2: {R_squared_BNS1_BNS2new}")
plt.figure(figsize=(8, 5))
plt.plot(BNS2Tshift[0:mrgBNS2index], ΔϕBNS1[0:mrgBNS2index], 'o', label='Numeric BNS1')
plt.plot(BNS2Tshift[0:mrgBNS2index], ΔϕBNSAnaF2[0:mrgBNS2index], label='Orig F2 fit')
plt.plot(BNS2Tshift[0:mrgBNS2index], ΔϕBNS1FitBNS2F1[0:mrgBNS2index], '-', label='BNS1 Prediction with BNS2 F1 Parameters')
plt.plot(BNS2Tshift[0:mrgBNS2index], ΔϕBNS1FitF1[0:mrgBNS2index], '-', label='BNS1 Prediction with BNS1 F1 Parameters')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Fit to New Data Using Chosen Parameters')
plt.legend()
plt.show()
# Out:
# R² for the new fit BNS1 with F1 BNS2: -0.7630422323530852

# %%
print("coefficients BNS1 fit","\n")
print("fitted coeffs PN BNS1 mrg:\n",pBNS1fit_PN)
print("fitted coeffs F1 BNS1 mrg:\n",pBNS1fit_F1)
print("fitted coeffs F2 BNS1 mrg:\n",pBNS1fit_F2)
#print(pBNS1matchedcoeffsmrg_F2)
# Out:
# coefficients BNS1 fit
#
# fitted coeffs PN BNS1 mrg:
#  [ -214.97071345  2016.48326597 -7744.5022154  13774.55231521
#  -9383.45862537   -42.62278165   151.06337602  -150.08559402]
# fitted coeffs F1 BNS1 mrg:
#  [ -214.97528759  2016.53288549 -7744.70144655 13774.90263286
#  -9383.68569816   -42.62263016   151.06252782  -150.08441077]
# fitted coeffs F2 BNS1 mrg:
#  [ -214.94904135  2016.23029914 -7743.40409987 13772.45168073
#  -9381.96489336   -42.62261525   151.06265795  -150.08487614]

# %%
print("coefficients BNS2 fit","\n")
print("fitted coeffs PN BNS2 mrg:\n",pBNS2fit_PN)
print("fitted coeffs F1 BNS2 mrg:\n",pBNS2fit_F1)
print("fitted coeffs F2 BNS2 mrg:\n",pBNS2fit_F2)
#print(pBNS2matchedcoeffsmrg_F2)
# Out:
# coefficients BNS2 fit
#
# fitted coeffs PN BNS2 mrg:
#  [  -1731.39551749   23056.69554327 -115265.13951359  253141.44996017
#  -204824.04269156     744.67890316   -4452.31031977    6599.02315053]
# fitted coeffs F1 BNS2 mrg:
#  [  -1709.58544064   22761.50655787 -113786.70945816  249902.54945476
#  -202212.41167941     735.35708525   -4397.80932046    6519.1232231 ]
# fitted coeffs F2 BNS2 mrg:
#  [  -1858.9120392    24802.45020387 -124091.21770051  272623.81153803
#  -220625.46032143     805.14504985   -4805.7625587     7117.09549267]

# %%
## Average BNS1 coefficients

BNS1n1   = np.average([pBNS1fit_PN[0], pBNS1fit_F1[0], pBNS1fit_F2[0]])
BNS1n1p5 = np.average([pBNS1fit_PN[1], pBNS1fit_F1[1], pBNS1fit_F2[1]])
BNS1n2   = np.average([pBNS1fit_PN[2], pBNS1fit_F1[2], pBNS1fit_F2[2]])
BNS1n2p5 = np.average([pBNS1fit_PN[3], pBNS1fit_F1[3], pBNS1fit_F2[3]])
BNS1n3   = np.average([pBNS1fit_PN[4], pBNS1fit_F1[4], pBNS1fit_F2[4]])
BNS1d1   = np.average([pBNS1fit_PN[5], pBNS1fit_F1[5], pBNS1fit_F2[5]])
BNS1d1p5 = np.average([pBNS1fit_PN[6], pBNS1fit_F1[6], pBNS1fit_F2[6]])
BNS1d2   = np.average([pBNS1fit_PN[7], pBNS1fit_F1[7], pBNS1fit_F2[7]])
BNS1averagecoeffs =np.array([BNS1n1,BNS1n1p5,BNS1n2,BNS1n2p5,BNS1n3,BNS1d1,BNS1d1p5,BNS1d2]) 
print("BNS1 averaged Coefficients",BNS1averagecoeffs)
BNS1ϕTideAvr = AnaϕTide1(Xhybarr[numBNS1ref:numBNS1fin],*BNS1averagecoeffs)
BNS1ϕTideAvr = BNS1ϕTideAvr - BNS1ϕTideAvr[0]
# Out:
# BNS1 averaged Coefficients [ -214.96501413  2016.41548353 -7744.20258727 13773.96887627
#  -9383.03640563   -42.62267568   151.06285393  -150.08496031]

# %%
## Average BNS2 coefficients
BNS2n1   = np.average([pBNS2fit_PN[0], pBNS2fit_F1[0], pBNS2fit_F2[0]])
BNS2n1p5 = np.average([pBNS2fit_PN[1], pBNS2fit_F1[1], pBNS2fit_F2[1]])
BNS2n2   = np.average([pBNS2fit_PN[2], pBNS2fit_F1[2], pBNS2fit_F2[2]])
BNS2n2p5 = np.average([pBNS2fit_PN[3], pBNS2fit_F1[3], pBNS2fit_F2[3]])
BNS2n3   = np.average([pBNS2fit_PN[4], pBNS2fit_F1[4], pBNS2fit_F2[4]])
BNS2d1   = np.average([pBNS2fit_PN[5], pBNS2fit_F1[5], pBNS2fit_F2[5]])
BNS2d1p5 = np.average([pBNS2fit_PN[6], pBNS2fit_F1[6], pBNS2fit_F2[6]])
BNS2d2   = np.average([pBNS2fit_PN[7], pBNS2fit_F1[7], pBNS2fit_F2[7]])
BNS2averagecoeffs =np.array([BNS2n1,BNS2n1p5,BNS2n2,BNS2n2p5,BNS2n3,BNS2d1,BNS2d1p5,BNS2d2]) 
print("BNS2 averaged Coefficients",BNS2averagecoeffs)
BNS2ϕTideAvr = AnaϕTide2(Xhybarr[numBNS2ref:numBNS2fin],*BNS2averagecoeffs)
BNS2ϕTideAvr = BNS2ϕTidemrg_PN - BNS2ϕTidemrg_PN[0]
# Out:
# BNS2 averaged Coefficients [  -1766.63099911   23540.217435   -117714.35555742  258555.93698432
#  -209220.6382308      761.72701276   -4551.96073298    6745.0806221 ]

# %%
BNS2ϕTideAvrBNS1 = AnaϕTide2(Xhybarr[numBNS2ref:numBNS2fin],*BNS1averagecoeffs)
BNS2ϕTideAvrBNS1 = BNS2ϕTideAvrBNS1 - BNS2ϕTideAvrBNS1[0]
BNS1ϕTideAvrBNS2 = AnaϕTide1(Xhybarr[numBNS1ref:numBNS1fin],*BNS2averagecoeffs)
BNS1ϕTideAvrBNS2 = BNS1ϕTideAvrBNS2 - BNS1ϕTideAvrBNS2[0]
#BNS1tΛ, BNS2tΛ = 791, 1540
#tΛratio = 1540/791
plt.plot(BNS1Tshift[20000:-2900], BNS1ϕTideF2[20000:-2900], color="orange", label=r"$\phi_{T, orig}$")
plt.plot(BNS1Tshift[20000:-1000], ΔϕBNS1BBH[20000:-1000], linestyle='solid', color='black',linewidth=1.00,label=r"$\phi^{BNS1}_{T, NR}$")
plt.plot(BNS1Tshift[20000:-3500], BNS1ϕTideAvr[20000:-3500], linestyle='dashed', color='darkblue',linewidth=1.2,label=r"$\phi^{BNS1}_{T,avr}$")
plt.plot(BNS1Tshift[20000:-3500], BNS1ϕTideAvrBNS2[20000:-3500], linestyle='dashed', color='red',linewidth=1.2,label=r"$\phi^{BNS1}_{T,avr, BNS2}$")
#plt.plot(BNS1Tshift[20000:-2500], BNS1ϕTidemrg_F2[20000:-2500], linestyle='dashed', color='blue',linewidth=1.2,label=r"$\phi^{BNS2}_{T,new}$")
plt.plot(BNS2Tshift[8780:-1000]+ΔTrefBNS12, ΔϕBNS2BBH[8780:-1000], linestyle='dotted', color='black',linewidth=1.1,label=r"$\phi^{BNS2}_{T, NR}$")
plt.plot(BNS2Tshift[8780:-1000]+ΔTrefBNS12, BNS2ϕTideAvr[8780:-1000], linestyle='dashdot', color='darkgreen',linewidth=1.2,label=r"$\phi^{BNS2}_{T,avr}$")
plt.plot(BNS2Tshift[8780:-1000]+ΔTrefBNS12, BNS2ϕTideAvrBNS1[8780:-1000], linestyle='dashdot', color='magenta',linewidth=1.2,label=r"$\phi^{BNS2}_{T,BNS1}$")
#plt.plot(BNS2Tshift[8780:-1]+ΔTrefBNS12, BNS2ϕTidemrg_F2[8780:-1], linestyle='dashdot', color='blue',linewidth=1.2,label=r"$\phi^{BNS2}_{T,new}$")
plt.xlabel('$t/M$',labelpad=-5)
plt.ylabel('$M\phi_{T}$',labelpad=-1)
plt.legend(loc=2)
print(BNS1Tshift[maxcorrectionIDX1],BNS2Tshift[maxcorrectionIDX2])
# Out:
# 3351.3 1926.9

# %%
#print(cutoffs1)
plt.plot(BNS1Tshift[mrgBNS1index:Tcutoff1],MϕBNS1hybarr_hvs[mrgBNS1index:Tcutoff1])
plt.plot(BNS1Tshift[mrgBNS1index:Tcutoff1],MϕBNS1NRnew[mrgBNS1index:])
plt.axvline(x=BNS1Tshift[mrgBNS1index], linestyle='dotted', color='magenta',linewidth=0.75)
plt.axvline(x=BNS1Tshift[Tcutoff1], linestyle='dotted', color='y',linewidth=0.75)
print(BNS1Tshift[Tcutoff1]-BNS1Tshift[mrgBNS1index], Tcutoff1)
# Out:
# 198.4000000000001 32466

# %%
#print(cutoffs2)
Tcutoff12 = cutoffs2[iTcutoff12]
MϕBNS2new_BNS1 = MϕBNS12hybarr_hvs[0:Tcutoff12]-MϕBNS12hybarr_hvs[0]
plt.plot(BNS2Tshift[0:Tcutoff2],MϕBNS2new)
plt.plot(BNS2Tshift[0:Tcutoff12+150],MϕBNS12hybarr_hvs[0:Tcutoff12+150])
plt.plot(BNS2Tshift, MϕBNS2NRarr)
plt.axvline(x=BNS2Tshift[mrgBNS2index], linestyle='dotted', color='magenta',linewidth=0.75)
plt.axvline(x=BNS2Tshift[Tcutoff2], linestyle='dotted', color='y',linewidth=0.75)
print(BNS2Tshift[Tcutoff2]-BNS2Tshift[mrgBNS2index], Tcutoff2,cutoffs12[iTcutoff12])
# Out:
# 185.5 19269 19268

# %%
#maxcorrectionIDX1=np.where(BNS1ϕTideNR==np.max(BNS1ϕTideNR))[0][0]
#maxcorrectionIDX2=np.where(BNS2ϕTideNR==np.max(BNS2ϕTideNR))[0][0]

#numIDX1 = maxcorrectionIDX1
#numIDX2 = maxcorrectionIDX2

#iT1pm = numIDX1-mrgBNS1index
#iT2pm = numIDX2-mrgBNS2index

#(cutoffs1 - numIDX1)

print(numIDX1,Tcutoff1, Tcutoff1-150,cutoffs1[73], iT1pm)
print(numIDX2,Tcutoff2, iT2pm)

#iTcutoff1 = np.abs((cutoffs1 - mrgBNS1index) - iT1pm).argmin()
#iTcutoff2 = np.abs((cutoffs2 - mrgBNS2index) - iT2pm).argmin()
#print("cutoffs1:\n",cutoffs1)
print("cutoffs1[iTcutoff1]-mrgBNS1index:\n",cutoffs1[iTcutoff1]-mrgBNS1index, cutoffs1[iTcutoff1]-150-mrgBNS1index)

#print("cutoffs2:\n",cutoffs2)
print("cutoffs2[iTcutoff2]-mrgBNS2index:\n", cutoffs2[iTcutoff2]-mrgBNS2index)
# Out:
# 33513 32466 32316 32466 2000
# 19269 19269 1855
# cutoffs1[iTcutoff1]-mrgBNS1index:
#  1984 1834
# cutoffs2[iTcutoff2]-mrgBNS2index:
#  1855

# %%
plt.plot(BNS1Tshift, ΔϕBNS1BBH, linestyle='solid', color='blue',linewidth=1.05,label=r"$M\phi^{BNS1}_{T, NR}$")
plt.plot(BNS2Tshift+ΔTrefBNS12, ΔϕBNS2BBH, linestyle='solid', color='green',linewidth=1.05,label=r"$M\phi^{BNS1}_{T, NR}$")
plt.xlabel('$t/M$',labelpad=-2)
plt.ylabel('$M\phi$',labelpad=-3)
plt.axvline(x=BNS1Tshift[Tcutoff1], linestyle='dotted', color='y',linewidth=0.75)
plt.axvline(x=BNS1Tshift[maxcorrectionIDX1], linestyle='dotted', color='magenta',linewidth=0.75)
plt.axvline(x=BNS2Tshift[maxcorrectionIDX2]+ΔTrefBNS12, linestyle='dotted', color='maroon',linewidth=0.75)
plt.xlim(0,3600)
plt.legend(loc=2)

# %%
## Plots for paper 
#ΔTmrg = BNS1Tshift[mrgBNS1index]-BNS2Tshift[mrgBNS2index]-ΔTrefBNS12

import matplotlib.ticker as ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1, 1))  # Adjust scientific notation threshold

matplotlib.rcParams.update({'font.size': 13, 'font.family': 'STIXGeneral', 'mathtext.fontset': 'stix'})
fig, axes = plt.subplots(2, 2, figsize=(10, 5))
fig.tight_layout()

axes[0,0].plot(BNS1Tshift[:mrgBNS1index+4500], (-BNS1ϕTidePN[:mrgBNS1index+4500]+ΔϕBNS1BBH[:mrgBNS1index+4500]), linestyle='dashed', color='maroon',linewidth=1.15,label=r"$M\phi^{BNS1}_{T, NR} - M\phi_{T, pN}^{BNS1}$")
axes[0,0].plot(BNS1Tshift[:mrgBNS1index+2000], (-BNS1ϕTideF1[:mrgBNS1index+2000]+ΔϕBNS1BBH[:mrgBNS1index+2000]), linestyle='dashdot', color='red',linewidth=1.15,label=r"$M\phi^{BNS1}_{T, NR} - M\phi_{T,F1}^{BNS1}$")
axes[0,0].plot(BNS1Tshift[:mrgBNS1index+2000], (-BNS1ϕTideF2[:mrgBNS1index+2000]+ΔϕBNS1BBH[:mrgBNS1index+2000]), linestyle=dashdotdot, color='magenta',linewidth=1.15,label=r"$M\phi^{BNS1}_{T, NR} - M\phi_{T,F2}^{BNS1}$")
axes[0,0].axvline(x=BNS1Tshift[mrgBNS1index], color='y', linestyle='dotted', linewidth=0.75)
#axes[0,0].axhline(y=3, color='y', ls='--',linewidth=0.75)
axes[0,0].set_xlabel('$t/M$',labelpad=-1)
axes[0,0].set_ylabel('$\Delta M\phi^{BNS1}_{T}$',labelpad=-10)
axes[0,0].legend(loc=2)
axes[0,0].set_xlim(2400,3260)
axes[0,0].set_ylim(-10,14)

axes[1,0].plot(BNS2Tshift[:mrgBNS2index+2000]+ΔTrefBNS12, (-BNS2ϕTidePN[:mrgBNS2index+2000]+ΔϕBNS2BBH[:mrgBNS2index+2000]), linestyle='dashed', color='maroon',linewidth=1.15,label=r"$M\phi^{BNS2}_{NR} - M\phi_{T, pN}^{BNS2}$")
axes[1,0].plot(BNS2Tshift[:mrgBNS2index+2000]+ΔTrefBNS12, (-BNS2ϕTideF1[:mrgBNS2index+2000]+ΔϕBNS2BBH[:mrgBNS2index+2000]), linestyle=dashdotdot, color='red',linewidth=1.15,label=r"$M\phi^{BNS2}_{NR} - M\phi_{T,F1}^{BNS2}$")
axes[1,0].plot(BNS2Tshift[:mrgBNS2index+2000]+ΔTrefBNS12, (-BNS2ϕTideF2[:mrgBNS2index+2000]+ΔϕBNS2BBH[:mrgBNS2index+2000]), linestyle='dotted', color='magenta',linewidth=1.20,label=r"$M\phi^{BNS2}_{NR} - M\phi_{T,F2}^{BNS2}$")
axes[1,0].axvline(x=BNS2Tshift[mrgBNS2index]+ΔTrefBNS12, color='y', linestyle='dotted', linewidth=0.75)
#axes[1,0].axhline(y=3, color='y', ls='--',linewidth=0.75)
axes[1,0].set_xlabel('$t/M$',labelpad=-1)
axes[1,0].set_ylabel('$\Delta M\phi^{BNS2}_{T}$',labelpad=-10)
axes[1,0].legend(loc=2)
axes[1,0].set_xlim(2100,3100)
#axes[1,0].yaxis.set_major_formatter(mtick.FormatStrFormatter('%.0e'))
axes[1,0].yaxis.set_major_formatter(formatter)
axes[1,0].set_ylim(-10,14)
#-ΔTmrg
axes[0,1].plot(BNS1Tshift, ΔϕBNS1BBH, linestyle='solid', color='blue',linewidth=1.05,label=r"$M\phi^{BNS1}_{T, NR}$")
axes[0,1].plot(BNS1Tshift, BNS1tΛ/BNS2tΛ*ΔϕBNS1BBH, linestyle='dotted', color='blue',linewidth=1.05,label=r"$\frac{\Lambda_1}{\Lambda_2}M\phi^{BNS1}_{T, NR}$")
axes[0,1].plot(BNS2Tshift+ΔTrefBNS12, ΔϕBNS2BBH, linestyle='solid', color='green',linewidth=1.05,label=r"$M\phi^{BNS2}_{T, NR}$")
axes[0,1].plot(BNS2Tshift+ΔTrefBNS12, BNS2tΛ/BNS1tΛ*ΔϕBNS2BBH, linestyle='dotted', color='green',linewidth=1.05,label=r"$\frac{\Lambda_2}{\Lambda_1} M\phi^{BNS2}_{T, NR}$")
axes[0,1].set_xlabel('$t/M$',labelpad=-1)
axes[0,1].set_ylabel('$\Lambda M\phi^{BNS}_{NR,T}$',labelpad=-7)
axes[0,1].legend(loc=2)
axes[0,1].set_xlim(2400,3500)
axes[0,1].axvline(x=BNS2Tshift[mrgBNS2index]+ΔTrefBNS12, color='y', linestyle='dotted', linewidth=0.75)
#axes[0,1].yaxis.set_major_formatter(mtick.FormatStrFormatter('%.0e'))
axes[0,1].yaxis.set_major_formatter(formatter)

y = 1/BNS1tΛ*ΔϕBNS1BBH
axes[1,1].plot(BNS1Tshift, 1/BNS1tΛ*ΔϕBNS1BBH, linestyle='solid', color='blue',linewidth=1.05,label=r"$\frac{1}{\Lambda_1} M\phi^{BNS1}_{T, NR}$")
axes[1,1].plot(BNS2Tshift+ΔTrefBNS12, 1/BNS2tΛ*ΔϕBNS2BBH, linestyle='solid', color='green',linewidth=1.05,label=r"$\frac{1}{\Lambda_2} M\phi^{BNS1}_{T, NR}$")
axes[1,1].set_xlabel('$t/M$',labelpad=-1)
axes[1,1].set_ylabel('$\Lambda M\phi^{BNS}_{NR,T}$',labelpad=-5)
axes[1,1].legend(loc=2)
axes[1,1].set_xlim(2400,3500)
axes[1,1].axvline(x=BNS2Tshift[mrgBNS2index]+ΔTrefBNS12, color='y', linestyle='dotted', linewidth=0.75)
#axes[1,1].yaxis.set_major_formatter(ticker.MathTextSciFormatter('%.0e'))
axes[1,1].yaxis.set_major_formatter(formatter)
#print(BNS1Tshift[mrgBNS1index]-BNS2Tshift[mrgBNS2index]+ΔTrefBNS12)
#print(BNS2tΛ*(BNS1Tshift[numIDX2]-BNS2Tshift[mrgBNS2index]))

#fig.savefig("Figure5.eps",bbox_inches='tight')

# %%
## Plots for paper 
dashdotdot = (0, (4, 1, 1, 1, 1, 1))
#Paper-quality plots
matplotlib.rcParams.update({'font.size': 14, 'font.family': 'STIXGeneral', 'mathtext.fontset': 'stix'})

fig = plt.figure(figsize=(10, 5))

axes1 = fig.add_axes([0.1, 0.1, 0.9, 0.8]) # main axes
axes2 = fig.add_axes([0.30, 0.21, 0.45, 0.30]) # inset axes
axes3 = fig.add_axes([0.30, 0.57, 0.45, 0.30]) # inset axes
#(x,y)

# main figure
#plt.plot(BNS1Tshift[0:],ΔϕBNS1BBH[0:]/BNS1tΛ, linestyle='dashed', color='maroon',linewidth=1.15,label=r"$\Delta M\phi_{NR, BNS1} - M\phi_{T, pN}^{BNS1}$")
#plt.plot(BNS2Tshift[0:]+ΔTrefBNS12,ΔϕBNS2BBH[0:]/BNS2tΛ, linestyle='dashed', color='maroon',linewidth=1.15,label=r"$\Delta M\phi_{NR, BNS1} - M\phi_{T, pN}^{BNS1}$")
#axes1.plot(BNS1Tshift[0:-900], ΔϕBNS1BBH[0:-900]/BNS1tΛ, linestyle='solid', color='blue',linewidth=1.00,label=r"$\phi^{BNS1}_{T, NR}$")
axes1.plot(BNS1Tshift[0:Tcutoff1+200], BNS1ϕTideNR[0:Tcutoff1+200], linestyle='solid', color='black',linewidth=1.0,label=r"$\phi^{BNS1}_{T, NR}$")
axes1.plot(BNS1Tshift[0:Tcutoff1+200], BNS1ϕTideF2[0:Tcutoff1+200]/BNS1tΛ, linestyle='solid', color='orange',linewidth=1.0,label=r"$\phi^{orig}_{T, F2}$")
axes1.plot(BNS1Tshift[0:Tcutoff1], BNS1ϕTidemrg_F2[0:Tcutoff1]/BNS1tΛ, linestyle='dashed', color='darkblue',linewidth=1.3,label=r"$\phi^{BNS1}_{T,new}$")
axes1.plot(BNS2Tshift[0:Tcutoff2+1400]+ΔTrefBNS12, BNS2ϕTideNR[0:Tcutoff2+1400], linestyle='dotted', color='black',linewidth=1.0,label=r"$\phi^{BNS2}_{T, NR}$")
axes1.plot(BNS2Tshift[0:Tcutoff2+1400]+ΔTrefBNS12, BNS2ϕTidemrg[0:Tcutoff2+1400]/BNS2tΛ, linestyle='dashdot', color='darkgreen',linewidth=1.3,label=r"$\phi^{BNS2}_{T,new}$")
#axes1.plot(BNS2Tshift[0:Tcutoff12+1000]+ΔTrefBNS12, BNS2ϕTidemrg_BNS1[0:Tcutoff12+1000]/BNS2tΛ, linestyle=dashdotdot, color='lightgreen',linewidth=1.3,label=r"$\phi^{BNS2}_{T,BNS1}$")
axes1.set_xlabel('$t/M$',labelpad=-5)
axes1.set_ylabel('$M\phi_{T}\slash \Lambda$',labelpad=-1)
axes1.legend(loc=2)
axes1.set_xlim(1000,3250)

# insert
axes2.plot(BNS2Tshift[8780:Tcutoff2+500]+ΔTrefBNS12,MϕBNS2NRarr[8780:Tcutoff2+500]-MϕBNS2NRarr[0]+ΔϕrefBNS12, linestyle='dotted', color='black',linewidth=1.15,label=r"$\phi^{BNS2}_{NR}$")
axes2.plot(BNS2Tshift[8780:Tcutoff2+500]+ΔTrefBNS12, MϕBNS2hybarr_hvs[8780:Tcutoff2+500]-MϕBNS2hybarr_hvs[0]+ΔϕrefBNS12, linestyle="dashdot", color='darkgreen',linewidth=1.20,label=r"$\phi^{BNS2}_{new}$")
axes2.plot(BNS2Tshift[8780:Tcutoff12+500]+ΔTrefBNS12,MϕBNS12hybarr_hvs[8780:Tcutoff12+500]-MϕBNS12hybarr_hvs[0]+ΔϕrefBNS12, linestyle=dashdotdot, color='lightgreen',linewidth=1.20,label=r"$\phi^{BNS2}_{BNS1}$")
axes2.axvline(x=BNS2Tshift[mrgBNS2index]+ΔTrefBNS12, color='y', linestyle='dashed', linewidth=0.75)
axes2.axvline(x=BNS2Tshift[Tcutoff2]+ΔTrefBNS12, color='brown', linestyle='dotted', linewidth=0.75)
axes2.set_ylabel('$M\phi$',labelpad=-1)
axes2.legend(loc=2)
axes2.set_xlim(2000,3150)

axes3.plot(BNS1Tshift[20000:Tcutoff1+500],MϕBNS1NRarr[20000:Tcutoff1+500]-MϕBNS1NRarr[0],linestyle='solid', color='black',linewidth=1.05,label=r"$\phi^{BNS1}_{NR}$")
axes3.plot(BNS1Tshift[20000:Tcutoff1+500],MϕBNS1hybarr_hvs[20000:Tcutoff1+500]-MϕBNS1hybarr_hvs[0], linestyle='dashed', color='blue',linewidth=1.15,label=r"$\phi^{BNS1}_{new}$")
axes3.axvline(x=BNS1Tshift[mrgBNS1index], color='y', linestyle='dashed', linewidth=1.0)
axes3.axvline(x=BNS1Tshift[Tcutoff1], color='brown', linestyle='dotted', linewidth=1.0)
#axes3.set_xlabel('$t/M$',labelpad=-5)
axes3.set_ylabel('$M\phi$',labelpad=-1)
axes3.legend(loc=2)
axes3.set_xlim(2000,3300)

fig.savefig("Figure6new.eps",bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.plot(BNS1Tshift[iTiniBNS2BNS1:iTfinBNS2BNS1-4000]-BNS1Tshift[iTiniBNS2BNS1], (ΔABNS1[0:-4000]), linestyle='dashed', color='blue',linewidth=1.15,label=r"$M\Delta phi^{BNS1}_{NR}$")
plt.plot(BNS2Tshift[0:mrgBNS2index],ΔABNS1FitPN[0:mrgBNS2index])
plt.plot(BNS2Tshift[0:mrgBNS2index],ΔABNS1FitA[0:mrgBNS2index])
plt.plot(BNS2Tshift[0:mrgBNS2index],ΔABNS1FitAna[0:mrgBNS2index])

# %%
plt.plot(BNS2Tshift[0:mrgBNS2index], (ΔABNS2[0:mrgBNS2index]), linestyle='dashed', color='blue',linewidth=1.15,label=r"$M\Delta phi^{BNS1}_{NR}$")
plt.plot(BNS2Tshift[0:mrgBNS2index],ΔABNS2FitPN[0:mrgBNS2index])
plt.plot(BNS2Tshift[0:mrgBNS2index],ΔABNS2FitA[0:mrgBNS2index])
plt.plot(BNS2Tshift[0:mrgBNS2index],ΔABNS2FitAna[0:mrgBNS2index])

# %%
plt.plot(BNS1Tshift[0:Tcutoff1-1800],BNS1AmpTideNR[0:Tcutoff1-1800],linestyle='solid', color='black',linewidth=1.10,label=r"$A^{BNS1}_{T, NR}$")
plt.plot(BNS1Tshift[0:Tcutoff1-100],BNS1PNATide[0:Tcutoff1-100],linestyle="dashdot", color='red',linewidth=1.10,label=r"$A^{BNS1}_{T, pN}$")
plt.plot(BNS1Tshift[0:Tcutoff1-1800], BNS1PNATidefit[0:-1800])
plt.plot(BNS1Tshift[0:Tcutoff1-1800], BNS1ATidefit[0:-1800])
plt.plot(BNS1Tshift[0:Tcutoff1-1800], BNS1AnaATidefit[0:-1800])
print(BNS1Tshift[Tcutoff1-1800], BNS1Tshift[mrgBNS1index])
# Out:
# 3066.6000000000004 3048.2000000000003

# %%
print("coefficients Amplitude BNS1 orig","\n")
print("initial coeffs PN:\n",initialPNAcoeffs1, initialPNAcoeffs2)
print("initial coeffs A:\n",initialAcoeffs1, initialAcoeffs2)
print("initial coeffs AnaA:\n",initialAnaAcoeffs1, initialAnaAcoeffs2)
#print(pBNS1matchedcoeffsmrg_F2)
# Out:
# coefficients Amplitude BNS1 orig
#
# initial coeffs PN:
#  [0 1] [0 1]
# initial coeffs A:
#  [-5.95797984  1.        ] [-6.23849772  1.        ]
# initial coeffs AnaA:
#  [-5.49535023  1.        ] [-6.07510822  1.        ]

# %%
print("coefficients Amplitude BNS1 fit","\n")
print("fitted coeffs PN BNS1 mrg:\n",matchedPNAcoeffs1)
print("fitted coeffs A BNS1 mrg:\n",matchedAcoeffs1)
print("fitted coeffs AnaA BNS1 mrg:\n",matchedAnaAcoeffs1)
#print(pBNS1matchedcoeffsmrg_F2)
# Out:
# coefficients Amplitude BNS1 fit
#
# fitted coeffs PN BNS1 mrg:
#  [-1.31756691  0.13180594]
# fitted coeffs A BNS1 mrg:
#  [-1.31756691  0.13180594]
# fitted coeffs AnaA BNS1 mrg:
#  [-1.31756788  0.13180629]

# %%
print("coefficients Amplitude BNS2 fit","\n")
print("fitted coeffs PN BNS2 mrg:\n",matchedPNAcoeffs2)
print("fitted coeffs A BNS2 mrg:\n",matchedAcoeffs2)
print("fitted coeffs AnaA BNS2 mrg:\n",matchedAnaAcoeffs2)
# Out:
# coefficients Amplitude BNS2 fit
#
# fitted coeffs PN BNS2 mrg:
#  [-1.77381066  0.25956178]
# fitted coeffs A BNS2 mrg:
#  [-1.77381056  0.25956176]
# fitted coeffs AnaA BNS2 mrg:
#  [-1.77381185  0.25956208]

# %%
## calculate SSR for the dataset

R_squared_BNS1A_orig = calculate_r_squared(ΔABNS1[0:mrgBNS2index], ΔABNS1A[0:mrgBNS2index])
print(f"R² for the original fit A BNS1: {R_squared_BNS1A_orig}")

R_squared_BNS2A_orig = calculate_r_squared(ΔABNS2[0:mrgBNS2index], ΔABNS2A[0:mrgBNS2index])
print(f"R² for the original fit A BNS2: {R_squared_BNS2A_orig}")

R_squared_BNS1A_new = calculate_r_squared(ΔABNS1[0:mrgBNS2index],  ΔABNS1FitA[0:mrgBNS2index])
print(f"R² for the new fit A BNS1: {R_squared_BNS1A_new}")

R_squared_BNS2A_new = calculate_r_squared(ΔABNS2[0:mrgBNS2index],  ΔABNS2FitA[0:mrgBNS2index])
print(f"R² for the new fit A BNS2: {R_squared_BNS2A_new}")
# Out:
# R² for the original fit A BNS1: -0.24903567331341336
# R² for the original fit A BNS2: -0.023721967951954026
# R² for the new fit A BNS1: 0.9853711442641332
# R² for the new fit A BNS2: 0.9452403607877288

# %%
# Compare residuals
# Calculate the sum of squared residuals
chosen_params_A = compare_residuals(ΔABNS1[0:mrgBNS2index], ΔABNS1FitA[0:mrgBNS2index], ΔABNS2[0:mrgBNS2index], ΔABNS2FitA[0:mrgBNS2index], matchedAcoeffs1, matchedAcoeffs2)
print(f"Chosen parameters: {chosen_params_A}")
# Out:
# Parameters from the first dataset provide a better fit.
# Chosen parameters: [-1.31756691  0.13180594]

# %%
BNS2ATidefit_BNS1 = AnaAmpTide2(Xhybarr[numBNS2ref:numBNS2ref+Tcutoff2],*matchedAcoeffs1)
BNS2ATidefit_BNS1 = BNS2ATidefit_BNS1 - BNS2ATidefit_BNS1[0]

# %%
## Plots for paper 
dashdotdot = (0, (4, 1, 1, 1, 1, 1))
#Paper-quality plots
matplotlib.rcParams.update({'font.size': 14, 'font.family': 'STIXGeneral', 'mathtext.fontset': 'stix'})

fig = plt.figure(figsize=(10, 5))

axes1 = fig.add_axes([0.1, 0.1, 0.9, 0.8]) # main axes
axes2 = fig.add_axes([0.28, 0.57, 0.40, 0.30]) # inset axes
axes3 = fig.add_axes([0.50, 0.16, 0.40, 0.30]) # inset axes

axes1.plot(BNS1Tshift[0:Tcutoff1],AmpBNS1NRnew[0:Tcutoff1],linestyle='solid', color='black',linewidth=1,label=r"$A^{BNS1}_{NR}$")
axes1.plot(BNS1Tshift[0:Tcutoff1],AmpBNS1new[0:Tcutoff1],linestyle='dashed', color='darkblue',linewidth=1.15,label=r"$A^{BNS1}_{new}$")
#axes1.plot(BNS1Tshift[0:mrgBNS1index],AmpBNS1pm[0:mrgBNS1index],linestyle='dashed', color='darkgreen',linewidth=1.15,label=r"$A^{BNS1}_{new}$")
#axes1.plot(BNS1Tshift[mrgBNS1index:Tcutoff1],AmpBNS1han,linestyle='dashed', color='darkgreen',linewidth=1.15)
axes1.plot(BNS2Tshift[0:Tcutoff2]+ΔTrefBNS12,AmpBNS2NRnew[0:Tcutoff2],linestyle='dotted', color='black',linewidth=1.15,label=r"$A^{BNS2}_{NR}$")
axes1.plot(BNS2Tshift[0:Tcutoff2]+ΔTrefBNS12,AmpBNS2new[0:Tcutoff2],linestyle='dashdot', color='darkgreen',linewidth=1.2,label=r"$A^{BNS2}_{new}$")
#axes1.plot(BNS2Tshift[0:mrgBNS2index]+ΔTrefBNS12,AmpBNS2pm[0:mrgBNS2index],linestyle='dashdot', color='darkgreen',linewidth=1.2,label=r"$A^{BNS2}_{new}$")
#axes1.plot(BNS2Tshift[mrgBNS2index:Tcutoff2]+ΔTrefBNS12,AmpBNS2han,linestyle='dashdot', color='darkgreen',linewidth=1.2)
axes1.set_xlabel('$t/M$',labelpad=-5)
axes1.set_ylabel('$A$',labelpad=-1)
#axes1.axvline(x=BNS1Tshift[Tcutoff1], color='brown', linestyle='dotted', linewidth=0.75)
axes1.legend(loc=2)
axes1.set_xlim(0,3250)

axes2.plot(BNS1Tshift[20000:Tcutoff1],AmpBNS1NRnew[20000:Tcutoff1]/BBH1Ampintarr[20000:Tcutoff1]-1, linestyle='solid', color='black',linewidth=1,label=r"$A^{BNS1}_{NR}$")
#axes2.plot(BNS1Tshift[20000:mrgBNS1index+1000],BNS1PNATide[20000:mrgBNS1index+1000], linestyle='dotted', color='maroon',linewidth=1.15,label=r"$A^{BNS1}_{T,PN}$")
axes2.plot(BNS1Tshift[20000:Tcutoff1],BNS1ATide[20000:Tcutoff1], linestyle=dashdotdot, color='red',linewidth=1.15,label=r"$A^{BNS1}_{T,d}$")
axes2.plot(BNS1Tshift[20000:Tcutoff1-1600],BNS1ATidefit[20000:Tcutoff1-1600], linestyle='dashed', color='darkblue',linewidth=1.15,label=r"$A^{BNS1}_{T,new}$")
#axes2.legend(loc=2)
#axes2.set_ylabel('$A_{T}^{BNS1}$',labelpad=-10)
axes2.axvline(x=BNS1Tshift[mrgBNS1index], color='y', linestyle='dashed', linewidth=0.75)
axes2.set_xlim(2000,3100)
axes2.set_ylim(-0.05,+0.4)
axes2.set_ylabel('$A_{T}$',labelpad=-1)
axes2.legend(loc=0)

line1, = axes3.plot(BNS2Tshift[8780:Tcutoff2]+ΔTrefBNS12,AmpBNS2NRnew[8780:Tcutoff2]/BBH2Ampintarr[8780:Tcutoff2]-1, linewidth=1.15,linestyle='dotted', color='black',label=r"$A^{BNS2}_{NR}$")
#axes3.plot(BNS2Tshift[8780:Tcutoff2]+ΔTrefBNS12,BNS2PNATide[8780:Tcutoff2], linestyle='dotted', color='maroon',linewidth=1.15,label=r"$A^{BNS2}_{T,PN}$")
line2, = axes3.plot(BNS2Tshift[8780:Tcutoff2]+ΔTrefBNS12,BNS2ATide[8780:Tcutoff2], linestyle=dashdotdot, color='red',linewidth=1.15,label=r"$A^{BNS2}_{T,d}$")
line3, = axes3.plot(BNS2Tshift[8780:Tcutoff2-1600]+ΔTrefBNS12,BNS2ATidefit[8780:Tcutoff2-1600], linestyle='dashdot', color='darkgreen',linewidth=1.15,label=r"$A^{BNS2}_{T,new}$")
line4, = axes3.plot(BNS2Tshift[8780:Tcutoff2-1600]+ΔTrefBNS12,BNS2ATidefit_BNS1[8780:Tcutoff2-1600], linestyle=dashdotdot, color='lightgreen',linewidth=1.15,label=r"$A^{BNS2}_{T,BNS1}$")
#axes3.legend(loc=2)
#axes3.set_ylabel('$A_{T}^{BNS2}$',labelpad=-5)
axes3.axvline(x=BNS2Tshift[mrgBNS2index]+ΔTrefBNS12, color='y', linestyle='dashed', linewidth=0.75)
axes3.set_xlim(2000,2950)
axes3.set_ylim(-0.05,+0.4)
axes3.set_ylabel('$A_{T}$',labelpad=-1)
first_legend = axes3.legend(handles=[line1, line2], loc='upper left')
axes3.add_artist(first_legend)
axes3.legend(handles=[line3, line4], loc='upper left', bbox_to_anchor=(0.3, 1))

fig.savefig("Figure7.eps",bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
chosen_params_ABNS1 = compare_models_residuals(ΔABNS1[0:mrgBNS2index], ΔABNS1FitPN[0:mrgBNS2index], ΔABNS1FitA[0:mrgBNS2index], ΔABNS1FitAna[0:mrgBNS2index], matchedPNAcoeffs1, matchedAcoeffs1, matchedAnaAcoeffs1)
print(f"Chosen Model parameters BNS1: {chosen_params_ABNS1}")
# Out:
# Chosen Model parameters BNS1: (array([-1.31756691,  0.13180594]), 'params2')

# %%
chosen_params_ABNS2 = compare_models_residuals(ΔABNS2[0:mrgBNS2index], ΔABNS2FitPN[0:mrgBNS2index], ΔABNS2FitA[0:mrgBNS2index], ΔABNS2FitAna[0:mrgBNS2index], matchedPNAcoeffs2, matchedAcoeffs2, matchedAnaAcoeffs2)
print(f"Chosen Model parameters BNS2: {chosen_params_ABNS2}")
# Out:
# Chosen Model parameters BNS2: (array([-1.77381056,  0.25956176]), 'params2')

# %%
import matplotlib.gridspec as gridspec
matplotlib.rcParams.update({'font.size': 14, 'font.family': 'STIXGeneral', 'mathtext.fontset': 'stix'})

# Create a new figure
fig = plt.figure(figsize=(15,6))

# Define the grid
gs = gridspec.GridSpec(1, 2, width_ratios=[1.5, 1])

# Add the first subplot with a rectangular shape
ax0 = plt.subplot(gs[0])

#ax0.plot(BNS1TNew,hplusAna, linestyle='solid', color='black',linewidth=1,label=r"$\h^{BBH}_{hyb}$")
ax0.plot(BNS1Tshift[11200:-1500],hplushybnew[11200:-1500], linestyle='solid', color='black',linewidth=1.05,label='$h^{BBH}_{+,hyb}$')
ax0.plot(BNS1Tnew[11200:],hplusBNS1new[11200:], linestyle='dashed', color='blue',linewidth=1.15,label='$h^{BNS1}_{+,new}$')
ax0.plot(BNS2Tnew+ΔTrefBNS12,hplusBNS2new, linestyle='dashdot', color='green',linewidth=1.15,label='$h^{BNS2}_{+,New}$')
ax0.set_xlabel("$t/M$", labelpad=-1)
ax0.set_ylabel("$h{+}$", labelpad=-5)
ax0.legend(loc='upper left',fontsize=19)
ax0.set_xlim(1120,3450)
#ax0.set_ylim(-1,1.05)
ax0.set_yticks([-1,-0.5,0,0.5, 1])


# Add the second subplot with a square shape
ax1 = plt.subplot(gs[1])
#ax1.gca().set_aspect('equal', adjustable='box')  # To keep the circle round
ax1.plot(2*xNS, 2*yNS, linestyle='dotted', color='red',linewidth=0.95)
ax1.plot(xABBH1hybarr[11200:]-xBBBH1hybarr[11200:],yABBH1hybarr[11200:]-yBBBH1hybarr[11200:],linestyle='solid', color='black',linewidth=0.95,label='${BBH}$')
ax1.plot(xABNS1new[11200:]-xBBNS1new[11200:],yABNS1new[11200:]-yBBNS1new[11200:],linestyle='dashed', color='blue',linewidth=1.15,label='${BNS1}$')
ax1.plot(xABNS2new-xBBNS2new,yABNS2new-yBBNS2new,linestyle='dashdot', color='green',linewidth=1.15,label='${BNS2}$')
ax1.set_xlabel("$x$", labelpad=-1)
ax1.set_ylabel("$y$", labelpad=-5)
ax1.legend(loc='upper left',fontsize=16)
ax1.set_xlim(-12.75,12.75)
ax1.set_ylim(-12.75,12.75)
#ax1.set_yticks([-5,0,5])

plt.tight_layout()
#plt.show()

#fig.savefig("Figure8.eps",bbox_inches='tight')

# %%
#plot rescaled analytic tides BNS 1
plt.title("Our Analytic Fit to BNS1 Tidal Phase Correction")
plt.plot(BNS1Tshift[0:Tcutoff1], (BNS1ϕintarr-BNS1ϕintarr[0])[0:Tcutoff1], 'k', linewidth=1.6)
plt.plot(BNS1Tshift[0:Tcutoff1], MϕBNS1new[0:Tcutoff1], '--b')
#plt.plot(BNS1Tshift[mrgBNS1index-3000:mrgBNS1index+2100], BNS1ϕTideF1[mrgBNS1index-3000:mrgBNS1index+2100], '--y', linewidth=0.6)
plt.axvline(x=BNS1Tshift[mrgBNS1index], color='c', ls='--')
plt.axvline(x=BNS1Tshift[Tcutoff1], color='y', ls='--')

# %%
#plot rescaled analytic tides BNS 2
#plt.title("Our Analytic Fit to BNS2 Tidal Phase Correction")
plt.plot(BNS2Tshift[mrgBNS2index-2000:mrgBNS2index+3000], ΔϕBNS2BBH[mrgBNS2index-2000:mrgBNS2index+3000], 'k', linewidth=0.6)
plt.plot(BNS2Tshift[mrgBNS2index-2000:mrgBNS2index+3000], BNS2ϕTidemrg[mrgBNS2index-2000:mrgBNS2index+3000], 'b')
plt.plot(BNS2Tshift[mrgBNS2index-2000:mrgBNS2index+3000], BNS2ϕTideF1[mrgBNS2index-2000:mrgBNS2index+3000], '--y', linewidth=0.6)
plt.axvline(x=BNS2Tshift[mrgBNS2index], color='c', ls='--')
plt.axvline(x=BNS2Tshift[Tcutoff2], color='c', ls='--')
plt.xlabel("$t/M$")
plt.ylabel("$M\phi_{tide}$") 
plt.legend(("$M\phi_{T,NR-BNS1}$","$M\phi_{T,NewFitMrg}$","$M\phi_{T,Orig.}$"),loc="upper left")

# %%
plt.plot(BNS1Tshift[mrgBNS1index-1000:mrgBNS1index+4000]-BNS1Tshift[mrgBNS1index], ΔϕBNS1BBH[mrgBNS1index-1000:mrgBNS1index+4000], 'k')
plt.plot(BNS2Tshift[mrgBNS2index-1000:mrgBNS2index+4000]-BNS2Tshift[mrgBNS2index], ΔϕBNS2BBH[mrgBNS2index-1000:mrgBNS2index+4000], '--k')
#plt.plot(BNS1Tshift[0:mrgBNS1index]-BNS1Tshift[mrgBNS1index], BNS1AnaATidefit[0:mrgBNS1index], '--b')

# %% [markdown]
# ### Tapering

# %%
# error between new analytic and numeric phase BNS1
print(MϕBNS1diff[cutoffs1[9]]/MϕBNS1NRarr[cutoffs1[9]]*1e2)
print(MϕBNS1diff[cutoffs1[10]]/MϕBNS1NRarr[cutoffs1[10]]*1e2)
# last cutoff point for BNS1 cutoffs1[9]
# Out:
# -0.008505345465155143
# -0.04763054310023518

# %%
# error between new analytic and numeric phase BNS2
print(MϕBNS2diff[cutoffs2[21]]/MϕBNS2NRarr[cutoffs2[21]]*1e2)
print(MϕBNS2diff[cutoffs2[22]]/MϕBNS2NRarr[cutoffs2[22]]*1e2)
# last cutoff point for BNS2 cutoffs2[21]
# Out:
# 1.9202216382880555
# 1.8750122305081378

# %%
#plt.figure(figsize=(6,6))
#title_font = {'size':'26'}
#plt.title("BNS1 with Tapered Tidal Phase Correction")
plt.plot(BNS1Tshift[mrgBNS1index-2000:maxcorrectionIDX1+1000],MϕBBH1hybarr[mrgBNS1index-2000:maxcorrectionIDX1+1000],'b', linewidth=0.7)
plt.plot(BNS1Tshift[mrgBNS1index-2000:maxcorrectionIDX1+1000],MϕBNS1NRarr[mrgBNS1index-2000:maxcorrectionIDX1+1000],'k', linewidth=0.7)
plt.plot(BNS1Tshift[mrgBNS1index-2000:maxcorrectionIDX1+1000],MϕBNS1hybarr_hvs[mrgBNS1index-2000:maxcorrectionIDX1+1000],'y') ##*this is the corrected phase
plt.plot(BNS1Tshift[mrgBNS1index-2000:maxcorrectionIDX1+1000],AnaBBH1ϕintarr[mrgBNS1index-2000:maxcorrectionIDX1+1000]-AnaBBH1ϕintarr[0]+BNS1ϕTideF2[mrgBNS1index-2000:maxcorrectionIDX1+1000], '--r',linewidth=1.10)
plt.axvline(x=BNS1Tshift[mrgBNS1index], color='c', ls='--')
plt.axvline(x=BNS1Tshift[maxcorrectionIDX1], color='m', ls='--', linewidth=0.7)
#plt.xlabel("$t/M$")
#plt.ylabel("$M\phi_{BNS1}$") 
#plt.legend(("$M\phi_{Ana-BBH}$","$M\phi_{NR-BNS1}$","$M\phi_{NewFit-BNS1}$","$M\phi_{Taper-BNS1}$", "$M\phi_{Orig.-BNS1}$"),loc="upper left")

# %% [markdown]
# ###  The amplitude correction.
# ##### We stop it at the cutoff time

# %%
# output for Amplitude
print("merger xPN, BNS1 (touch, approx and hyb)","\n",Xc1, AnaXmrg1, Xmerge1)
print("merger xPN, BNS2 (touch, approx and hyb)","\n",Xc2, AnaXmrg2, Xmerge2)
# Out:
# merger xPN, BNS1 (touch, approx and hyb)
#  0.1797630480473424 0.17399671859435578 0.16290177558301758
# merger xPN, BNS2 (touch, approx and hyb)
#  0.17334293918850874 0.15635620805740696 0.15345344483504364

# %%
print("BNS1 simulation merger x, A, d : ","\n",Xmerge1, Amerge1, dA1)
print("BNS1 approximation merger x, A, d:","\n", AnaXmrg1, AnaAmrg1, dAnaA1)
print("BNS1 original coefficients:","\n",initialPNAcoeffs1, initialAcoeffs1,initialAnaAcoeffs1)
print("BNS1 matched coefficients:","\n",matchedPNAcoeffs1, matchedAcoeffs1, matchedAnaAcoeffs1)
# Out:
# BNS1 simulation merger x, A, d :
#  0.16290177558301758 0.5955198324969816 -5.957979838794721
# BNS1 approximation merger x, A, d:
#  0.17399671859435578 0.593776017882684 -5.495350226132249
# BNS1 original coefficients:
#  [0 1] [-5.95797984  1.        ] [-5.49535023  1.        ]
# BNS1 matched coefficients:
#  [-1.31756691  0.13180594] [-1.31756691  0.13180594] [-1.31756788  0.13180629]

# %%
print("BNS2 simulation merger x, A, d : ","\n",Xmerge2, Amerge2, dA2)
print("BNS2 approximation merger x, A, d:","\n", AnaXmrg2, AnaAmrg2, dAnaA2)
print("BNS2 original coefficients:","\n",initialPNAcoeffs2, initialAcoeffs2,initialAnaAcoeffs2)
print("BNS2 matched coefficients:","\n",matchedPNAcoeffs2, matchedAcoeffs2, matchedAnaAcoeffs2)
print("BNS2/BNS1 matched coefficients:","\n",matchedAcoeffs2/matchedAcoeffs1)
# Out:
# BNS2 simulation merger x, A, d :
#  0.15345344483504364 0.5587719081791876 -6.238497721654944
# BNS2 approximation merger x, A, d:
#  0.15635620805740696 0.5324469371456251 -6.075108217794184
# BNS2 original coefficients:
#  [0 1] [-6.23849772  1.        ] [-6.07510822  1.        ]
# BNS2 matched coefficients:
#  [-1.77381066  0.25956178] [-1.77381056  0.25956176] [-1.77381185  0.25956208]
# BNS2/BNS1 matched coefficients:
#  [1.34627741 1.96927204]

# %%
#plot
plt.title("BNS1 Tidal Amplitude Correction Comparison")
plt.plot(BNS1Tshift[0:Tcutoff1],fact1*BNS1Ampintarr[0:Tcutoff1],'--r')
#plt.plot(BNS1Tshift[0:Tcutoff1],AnaBBH1Aintarr[0:Tcutoff1],'--k')
#plt.plot(BNS1Tshift[0:mrgBNS1index],Aclip1[0:mrgBNS1index],'b')
plt.plot(BNS1Tshift[0:mrgBNS1index],AmpBNS1pm[0:mrgBNS1index],'b')
plt.plot(BNS1Tshift[mrgBNS1index:Tcutoff1],AmpBNS1han)
plt.xlabel("$t/M$")
plt.ylabel("$A_{T, BNS1}$") 
plt.legend(("$A_{T-BNS1}$","$A_{Fit-BNS1}$","$A_{Ana-BNS1}$","$A_{Clip}$","$A_{half-Hann}$" ),loc="upper left")

# %%
#plot
plt.title("BNS2 Tidal Amplitude Correction Comparison")
plt.plot(BNS2Tshift[0:Tcutoff2],fact2*BNS2Ampintarr[0:Tcutoff2],'--r')
plt.plot(BNS2Tshift[0:Tcutoff2],AnaBBH2Aintarr[0:Tcutoff2],'--k')
#plt.plot(BNS1Tshift[0:mrgBNS1index],AmpBNS1premrg[0:mrgBNS1index],'b')
plt.plot(BNS2Tshift[0:mrgBNS2index],AmpBNS2pm[0:mrgBNS2index],'b')
plt.plot(BNS2Tshift[mrgBNS2index:Tcutoff2],AmpBNS2han)
plt.xlabel("$t/M$")
plt.ylabel("$A_{T, BNS2}$") 
plt.legend(("$A_{T-BNS2}$","$A_{Fit-BNS2}$","$A_{Ana-BNS2}$"),loc="upper left")

# %% [markdown]
# ### Complete Waveforms

# %%
plt.plot(BNS1Tshift[0:-1500],hplushybnew[0:-1500], linestyle='solid', color='black',linewidth=0.95,label='$h^{BBH}_{+,hyb}$')
plt.plot(BNS1Tnew,hplusBNS1new, linestyle='dashed', color='blue',linewidth=1.15,label='$h^{BNS1}_{+,new}$')
plt.plot(BNS2Tnew+ΔTrefBNS12,hplusBNS2new, linestyle='dashdot', color='cyan',linewidth=1.15,label='$h^{BNS1}_{+,new}$')

print(BNS1Tshift[11200],ΔTrefBNS12)
# Out:
# 1120.0 1165.2000000000003

# %%
# plot the individual orbits for hybrid BBH and BNS1 

plt.figure(figsize=(10,10)) # To ensure the aspect ratio such that the circle isn't elliptical
plt.gca().set_aspect('equal', adjustable='box')  # To keep the circle round
plt.plot(2*xNS, 2*yNS, linestyle='dotted', color='red',linewidth=0.7)
#plt.xlim(-rNS-1, rNS+1)
#plt.ylim(-rNS-1, rNS+1)

#plt.title("Parametric Plots of BNS1 NR Orbits")
plt.xlabel("$x_A$")
plt.ylabel("$y_A$")
plt.plot(xABBH1hybarr[11200:-1500]-xBBBH1hybarr[11200:-1500],yABBH1hybarr[11200:-1500]-yBBBH1hybarr[11200:-1500],linestyle='solid', color='black',linewidth=0.95)
plt.plot(xABNS1new[11200:Tcutoff1]-xBBNS1new[11200:Tcutoff1],yABNS1new[11200:Tcutoff1]-yBBNS1new[11200:Tcutoff1],linestyle='dashed', color='blue',linewidth=1.15)
plt.plot(xABNS2new[0:Tcutoff2]-xBBNS2new[0:Tcutoff2],yABNS2new[0:Tcutoff2]-yBBNS2new[0:Tcutoff2],linestyle='dashdot', color='green',linewidth=1.15)

print("beginning separation",RBBH1hybarr[11200],m*RBBH1hybarr[11200]/cL*1e3)
print("last radius BBH,touch, BNS1, BNS2",RBBH1hybarr[-1500], RToM, RBNS1new[-10],RBNS2new[-100])
print("radii in km",m*RBBH1hybarr[-1500]/cL*1e3, m*RToM/cL*1e3, m*RBNS1new[-10]/cL*1e3,m*RBNS2new[-100]/cL*1e3)
# Out:
# beginning separation 12.648473957117988 0.3017638690115274
# last radius BBH,touch, BNS1, BNS2 1.5586015418757069 5.562878527385895 2.6437445776634165 5.25587787277741
# radii in km 0.03718469383091589 0.13271765060008944 0.0630737427407202 0.1253933120563402
